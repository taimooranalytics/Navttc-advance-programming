# %%
 import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
pwd
# Out:
# 'C:\\Users\\LAB-006\\Untitled Folder 1'

# %%
df = pd.read_csv('salary.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.plot.line(marker="o" )
plt.title('salary increase by yearsExperience')
plt.ylabel('salary')
plt.xlabel('Years of Experience')
plt.tight_layout()
plt.legend()
plt.show()

# %%
# Splitting variables
X = df.iloc[:, :1]  # independent
y = df.iloc[:, 1:]  # dependent

# %%
x,y
# Out:
# (    YearsExperience
#  0               1.1
#  1               1.3
#  2               1.5
#  3               2.0
#  4               2.2
#  5               2.9
#  6               3.0
#  7               3.2
#  8               3.2
#  9               3.7
#  10              3.9
#  11              4.0
#  12              4.0
#  13              4.1
#  14              4.5
#  15              4.9
#  16              5.1
#  17              5.3
#  18              5.9
#  19              6.0
#  20              6.8
#  21              7.1
#  22              7.9
#  23              8.2
#  24              8.7
#  25              9.0
#  26              9.5
#  27              9.6
#  28             10.3
#  29             10.5,
#        Salary
#  0    39343.0
#  1    46205.0
#  2    37731.0
#  3    43525.0
#  4    39891.0
#  5    56642.0
#  6    60150.0
#  7    54445.0
#  8    64445.0
#  9    57189.0
#  10   63218.0
#  11   55794.0
#  12   56957.0
#  13   57081.0
#  14   61111.0
#  15   67938.0
#  16   66029.0
#  17   83088.0
#  18   81363.0
#  19   93940.0
#  20   91738.0
#  21   98273.0
#  22  101302.0
#  23  113812.0
#  24  109431.0
#  25  105582.0
#  26  116969.0
#  27  112635.0
#  28  122391.0
#  29  121872.0)

# %%
train_test_split(x, y, test_size = 0.2)
# Out:
# [    YearsExperience
#  7               3.2
#  13              4.1
#  23              8.2
#  27              9.6
#  19              6.0
#  1               1.3
#  18              5.9
#  4               2.2
#  24              8.7
#  21              7.1
#  3               2.0
#  16              5.1
#  17              5.3
#  22              7.9
#  20              6.8
#  26              9.5
#  25              9.0
#  14              4.5
#  11              4.0
#  29             10.5
#  28             10.3
#  9               3.7
#  5               2.9
#  6               3.0,
#      YearsExperience
#  12              4.0
#  8               3.2
#  2               1.5
#  0               1.1
#  10              3.9
#  15              4.9,
#        Salary
#  7    54445.0
#  13   57081.0
#  23  113812.0
#  27  112635.0
#  19   93940.0
#  1    46205.0
#  18   81363.0
#  4    39891.0
#  24  109431.0
#  21   98273.0
#  3    43525.0
#  16   66029.0
#  17   83088.0
#  22  101302.0
#  20   91738.0
#  26  116969.0
#  25  105582.0
#  14   61111.0
#  11   55794.0
#  29  121872.0
#  28  122391.0
#  9    57189.0
#  5    56642.0
#  6    60150.0,
#       Salary
#  12  56957.0
#  8   64445.0
#  2   37731.0
#  0   39343.0
#  10  63218.0
#  15  67938.0]

# %%
# Splitting dataset into test/train
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
#     YearsExperience
# 6               3.0
# 12              4.0
# 19              6.0
# 22              7.9
# 3               2.0
# 25              9.0
# 7               3.2
# 4               2.2
# 27              9.6
# 13              4.1
# 17              5.3
# 15              4.9
# 11              4.0
# 20              6.8
# 14              4.5
# 9               3.7
# 8               3.2
# 18              5.9
# 0               1.1
# 28             10.3
# 29             10.5
# 26              9.5
# 10              3.9
# 23              8.2

# %%
 y_train
# Out:
#       Salary
# 27  112635.0
# 11   55794.0
# 17   83088.0
# 22  101302.0
# 5    56642.0
# 16   66029.0
# 8    64445.0
# 14   61111.0
# 23  113812.0
# 20   91738.0
# 1    46205.0
# 29  121872.0
# 6    60150.0
# 4    39891.0
# 18   81363.0
# 19   93940.0
# 9    57189.0
# 7    54445.0
# 25  105582.0
# 3    43525.0
# 0    39343.0
# 21   98273.0
# 15   67938.0
# 12   56957.0

# %%
x_test
# Out:
#     YearsExperience
# 2               1.5
# 5               2.9
# 16              5.1
# 24              8.7
# 1               1.3
# 21              7.1

# %%
y_test
# Out:
#       Salary
# 2    37731.0
# 28  122391.0
# 13   57081.0
# 10   63218.0
# 26  116969.0
# 24  109431.0

# %%
reg = LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_pred_test = reg.predict(x_test) 

x_pred_test
# Out:
# array([[78788.42363513],
#        [77086.82824112],
#        [74412.89262196],
#        [70037.36160879],
#        [79031.50869141],
#        [71982.04205908]])

# %%
y_test
# Out:
#       Salary
# 2    37731.0
# 28  122391.0
# 13   57081.0
# 10   63218.0
# 26  116969.0
# 24  109431.0

# %%
plt.scatter(x_train, y_train, color = 'lightcoral')
plt.plot(x_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience(training set)')
plt.xlabel('years of Experience')
plt.ylabel('Salary')
plt.legend(['x_train/pred(y_test)', 'x_train/y_train'], title = 'sal/exp', loc='best', facecolor='white')
plt.box(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 plt.scatter(x_train, y_train, color = 'lightcoral')
# ----> 2 plt.plot(x_train, y_pred_train, color = 'firebrick')
#       3 plt.title('Salary vs Experience(training set)')
#       4 plt.xlabel('years of Experience')
#
# NameError: name 'y_pred_train' is not defined

# %%
plt.scatter(x_test, y_test, color = 'lightcoral')
plt.plot(x_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience(training set)')
plt.xlabel('years of Experience')
plt.ylabel('Salary')
plt.legend(['x_train/pred(y_test)', 'x_train/y_train'], title = 'sal/exp', loc='best', facecolor='white')
plt.box(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 plt.scatter(x_test, y_test, color = 'lightcoral')
# ----> 2 plt.plot(x_test, y_pred_test, color = 'firebrick')
#       3 plt.title('Salary vs Experience(training set)')
#       4 plt.xlabel('years of Experience')
#
# NameError: name 'y_pred_test' is not defined

# %%
# Out:
# 'C:\\Users\\LAB-006\\Untitled Folder 1'
